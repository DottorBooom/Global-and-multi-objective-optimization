# %% [markdown]
# # Policy Optimisation
#
# We will use the ```xcs``` Python library that, obviously, implements the XCS algorithm

# %%
# %pip install xcs
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/xcs/
# Collecting xcs
#   Downloading xcs-1.0.0-py3-none-any.whl.metadata (221 bytes)
# Downloading xcs-1.0.0-py3-none-any.whl (53 kB)
# Installing collected packages: xcs
# Successfully installed xcs-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from xcs import XCSAlgorithm
from xcs.scenarios import MUXProblem, ScenarioObserver

# %% [markdown]
# The problem that we want solve is the _Multiplexer Problem_ with $11$ bits. Three of the bits are used to address the remaining eight bits. The following is adapted from the ```xcs``` library tutorial.

# %%
# The multiplexer problem with 11 has 8 bits as input and 3 to select
scenario = ScenarioObserver(MUXProblem(50000))

# %% [markdown]
# The ```XCSAlgorithm``` object has some reasonable defaults...

# %%
algorithm = XCSAlgorithm()

# %% [markdown]
# That can be easily explored and modified:

# %%
print(algorithm.learning_rate)
# Out:
# 0.15

# %% [markdown]
# We create a new scenario and we run the resulting model on it to learn a set of rules

# %%
model = algorithm.new_model(scenario)
model.run(scenario, learn=True)

# %% [markdown]
# How many rules does the learned model have?

# %%
# Here the number of rules
print(len(model))
# Out:
# 125

# %% [markdown]
# What are the rules with the best fitness?

# %%
# From the output we can see the fitness.
# The first three bits define the position and the value of the bit, with some probabilities
# The algorithm have find a "policy" or bettere to say a set of rules that define the behavior of the system

for rule in model:
    if rule.fitness > .5:
        print(f"{rule.condition} => {rule.action}\t {rule.fitness}")
# Out:
# 0001####### => True	 0.8157891624151895
# 010##1##### => True	 0.6819925224215757
# 0000####### => True	 0.8352575487357687
# 010##0##### => True	 0.533365324489684
# 100####1### => True	 0.6799140909959224
# 110######0# => True	 0.924125694219482
# 101####11## => True	 0.6046614038820011
# 001#1###### => True	 0.5054741105193185

# %% [markdown]
# We can also print the entire model:

# %%
# And here a more described statistic

print(model)
# Out:
# #000#100000 => True
#     Time Stamp: 47267
#     Average Reward: 1e-05
#     Error: 1e-05
#     Fitness: 1e-05
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 1#101##11## => True
#     Time Stamp: 49934
#     Average Reward: 0.875
#     Error: 0.13541666666666669
#     Fitness: 0.012127251467608253
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# #1#1####### => True
#     Time Stamp: 49980
#     Average Reward: 0.5409023702712538
#     Error: 0.44178429973899974
#     Fitness: 0.013072332759138655
#     Experience: 20
#     Action Set Size: 13.889454579696539
#     Numerosity: 1
# 10110##1### => True
#     Time Stamp: 49911
#     Average Reward: 0.22111904633586232
#     Error: 0.21316479786352743
#     Fitness: 0.013392499213254656
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 11#1#####1# => True
#     Time Stamp: 49964
#     Average Reward: 0.7888013153089439
#     Error: 0.26852694147825207
#     Fitness: 0.013424274955039827
#     Experience: 47
#     Action Set Size: 11.560363270925128
#     Numerosity: 1
# 10#0#0###0# => True
#     Time Stamp: 49970
#     Average Reward: 0.8333333333333333
#     Error: 0.1388888888888889
#     Fitness: 0.013651059279781191
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# ##1#1####1# => True
#     Time Stamp: 49995
#     Average Reward: 0.35470833333333335
#     Error: 0.36973819444444445
#     Fitness: 0.0137590275846847
#     Experience: 9
#     Action Set Size: 10.846145833333333
#     Numerosity: 1
# 101#01#01#1 => True
#     Time Stamp: 49507
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.015000850000000003
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# ##1##1###1# => True
#     Time Stamp: 49995
#     Average Reward: 0.39083333333333337
#     Error: 0.36231250000000004
#     Fitness: 0.01530755915637133
#     Experience: 8
#     Action Set Size: 11.959999999999999
#     Numerosity: 1
# 00##1###### => True
#     Time Stamp: 49993
#     Average Reward: 0.75
#     Error: 0.22916666666666669
#     Fitness: 0.015445360766181391
#     Experience: 4
#     Action Set Size: 16.0
#     Numerosity: 1
# 100#1#0#### => True
#     Time Stamp: 49978
#     Average Reward: 0.75
#     Error: 0.27083333333333337
#     Fitness: 0.016057344047626595
#     Experience: 4
#     Action Set Size: 12.75
#     Numerosity: 1
# 111######01 => True
#     Time Stamp: 49962
#     Average Reward: 0.895398990951547
#     Error: 0.15400114082193872
#     Fitness: 0.01939482938903767
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 110###1#### => True
#     Time Stamp: 49950
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.019410161438203732
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 0#######1## => False
#     Time Stamp: 49957
#     Average Reward: 0.7019032466384485
#     Error: 0.4097719121253499
#     Fitness: 0.022214850659464557
#     Experience: 210
#     Action Set Size: 16.02984044036224
#     Numerosity: 1
# #000#0##### => True
#     Time Stamp: 49987
#     Average Reward: 0.38305020677083335
#     Error: 0.40489344955078127
#     Fitness: 0.023396241807077334
#     Experience: 13
#     Action Set Size: 11.302935372916668
#     Numerosity: 1
# 1###1#0##01 => True
#     Time Stamp: 49978
#     Average Reward: 0.7591666666666667
#     Error: 0.3211111111111111
#     Fitness: 0.02660892288279259
#     Experience: 8
#     Action Set Size: 13.655000000000001
#     Numerosity: 1
# 11####0##10 => True
#     Time Stamp: 49968
#     Average Reward: 0.7295833333333334
#     Error: 0.3021041666666667
#     Fitness: 0.028530157954559793
#     Experience: 8
#     Action Set Size: 12.15
#     Numerosity: 1
# #11##1##0## => True
#     Time Stamp: 49968
#     Average Reward: 0.4656710933684244
#     Error: 0.4253570299769664
#     Fitness: 0.028728721221584732
#     Experience: 16
#     Action Set Size: 11.280046032506428
#     Numerosity: 1
# 10#00##0### => True
#     Time Stamp: 49806
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.02878964216597484
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 111###1#### => True
#     Time Stamp: 49964
#     Average Reward: 0.5666666666666667
#     Error: 0.3541666666666667
#     Fitness: 0.029293380251756814
#     Experience: 7
#     Action Set Size: 10.316666666666668
#     Numerosity: 1
# 0#0##0##### => True
#     Time Stamp: 49987
#     Average Reward: 0.33333333333333337
#     Error: 0.2777777777777778
#     Fitness: 0.029949802282970367
#     Experience: 3
#     Action Set Size: 15.666666666666666
#     Numerosity: 1
# #1###01###1 => True
#     Time Stamp: 49962
#     Average Reward: 0.6
#     Error: 0.31333333333333335
#     Fitness: 0.03237870227629044
#     Experience: 5
#     Action Set Size: 13.4
#     Numerosity: 1
# 0#########1 => True
#     Time Stamp: 49993
#     Average Reward: 0.8333333333333334
#     Error: 0.21388888888888888
#     Fitness: 0.03445026075298826
#     Experience: 6
#     Action Set Size: 13.0
#     Numerosity: 1
# 100###1#111 => True
#     Time Stamp: 49688
#     Average Reward: 0.7797083333333334
#     Error: 0.1857220486111111
#     Fitness: 0.03574342804844335
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 100#1#0##01 => True
#     Time Stamp: 49978
#     Average Reward: 0.8795833333333334
#     Error: 0.16055555555555556
#     Fitness: 0.03628337587321365
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 101011##111 => True
#     Time Stamp: 49995
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.03750849825810139
#     Experience: 1
#     Action Set Size: 14.0
#     Numerosity: 1
# #1##0#0##1# => True
#     Time Stamp: 49926
#     Average Reward: 0.738996875
#     Error: 0.34655414930555556
#     Fitness: 0.037532763090897925
#     Experience: 10
#     Action Set Size: 11.461135416666666
#     Numerosity: 1
# 10#10##00#1 => True
#     Time Stamp: 49723
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.0387878049350292
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 0###0#1#### => False
#     Time Stamp: 49937
#     Average Reward: 0.7649447347644163
#     Error: 0.362377686497327
#     Fitness: 0.041617045689957055
#     Experience: 24
#     Action Set Size: 17.504162620113668
#     Numerosity: 1
# 00##11##### => True
#     Time Stamp: 49936
#     Average Reward: 0.8808254837441405
#     Error: 0.18506512219775398
#     Fitness: 0.04204464172870246
#     Experience: 26
#     Action Set Size: 12.718445759804656
#     Numerosity: 1
# 111###0###1 => True
#     Time Stamp: 49821
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.042046708886690286
#     Experience: 1
#     Action Set Size: 17.0
#     Numerosity: 1
# #11##0####0 => True
#     Time Stamp: 49921
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.042531440119182515
#     Experience: 1
#     Action Set Size: 8.0
#     Numerosity: 1
# 01####1#### => True
#     Time Stamp: 49960
#     Average Reward: 0.5654374999999999
#     Error: 0.40215034722222226
#     Fitness: 0.04504380350121622
#     Experience: 9
#     Action Set Size: 14.994729166666668
#     Numerosity: 1
# #11##1##0#1 => True
#     Time Stamp: 49966
#     Average Reward: 0.6430235968636068
#     Error: 0.3493620555190104
#     Fitness: 0.04707796900762341
#     Experience: 15
#     Action Set Size: 13.974935810350585
#     Numerosity: 1
# 0001###1### => True
#     Time Stamp: 49965
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.04754125587881289
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# #11#1###1#1 => True
#     Time Stamp: 49770
#     Average Reward: 0.6455277414263785
#     Error: 0.367418978602955
#     Fitness: 0.04927677896661685
#     Experience: 17
#     Action Set Size: 10.066794610920383
#     Numerosity: 1
# #011##10111 => True
#     Time Stamp: 49779
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0500085
#     Experience: 1
#     Action Set Size: 3.0
#     Numerosity: 1
# #000###10## => True
#     Time Stamp: 49987
#     Average Reward: 0.7083333333333334
#     Error: 0.22430555555555554
#     Fitness: 0.051267825636872745
#     Experience: 7
#     Action Set Size: 14.141666666666666
#     Numerosity: 1
# 01###0##### => True
#     Time Stamp: 49960
#     Average Reward: 0.2307676723609091
#     Error: 0.3383987716984591
#     Fitness: 0.05160517515180434
#     Experience: 17
#     Action Set Size: 10.245010970908009
#     Numerosity: 1
# 0##1#0##### => True
#     Time Stamp: 49993
#     Average Reward: 0.5
#     Error: 0.25
#     Fitness: 0.05256284318581118
#     Experience: 2
#     Action Set Size: 13.5
#     Numerosity: 1
# 1111#1##### => True
#     Time Stamp: 49964
#     Average Reward: 0.5
#     Error: 0.33333333333333337
#     Fitness: 0.05296880812769477
#     Experience: 4
#     Action Set Size: 12.25
#     Numerosity: 1
# 010#0#0#### => True
#     Time Stamp: 49980
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.05303117015378273
#     Experience: 1
#     Action Set Size: 12.0
#     Numerosity: 1
# 0#01######0 => True
#     Time Stamp: 49965
#     Average Reward: 0.8333333333333334
#     Error: 0.16111111111111112
#     Fitness: 0.053736440903736346
#     Experience: 6
#     Action Set Size: 17.833333333333336
#     Numerosity: 1
# 00#0###0### => True
#     Time Stamp: 49936
#     Average Reward: 0.5429375
#     Error: 0.38509131944444447
#     Fitness: 0.05675951664699466
#     Experience: 9
#     Action Set Size: 10.094000000000001
#     Numerosity: 1
# 1#1#####001 => True
#     Time Stamp: 49962
#     Average Reward: 0.5474951250325522
#     Error: 0.39819842939105904
#     Fitness: 0.06213705229019631
#     Experience: 14
#     Action Set Size: 11.436233628333333
#     Numerosity: 1
# 1###1##1### => True
#     Time Stamp: 49978
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.06834086921053767
#     Experience: 1
#     Action Set Size: 8.0
#     Numerosity: 1
# 010##1###1# => True
#     Time Stamp: 49924
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.06980553703660358
#     Experience: 15
#     Action Set Size: 17.937105265329098
#     Numerosity: 1
# 00#10###### => True
#     Time Stamp: 49939
#     Average Reward: 0.713492385888335
#     Error: 0.3779989276705959
#     Fitness: 0.07029342027813715
#     Experience: 31
#     Action Set Size: 11.145503624397652
#     Numerosity: 1
# 0#1#1###### => True
#     Time Stamp: 49993
#     Average Reward: 0.4
#     Error: 0.33666666666666667
#     Fitness: 0.07117113496794152
#     Experience: 5
#     Action Set Size: 11.6
#     Numerosity: 1
# 00011###### => True
#     Time Stamp: 49965
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0715720503788541
#     Experience: 11
#     Action Set Size: 15.2959259375
#     Numerosity: 1
# #11#1##1#1# => True
#     Time Stamp: 49968
#     Average Reward: 0.353121875
#     Error: 0.37785746527777775
#     Fitness: 0.076303807661345
#     Experience: 10
#     Action Set Size: 12.121120833333334
#     Numerosity: 1
# 0#1#####110 => True
#     Time Stamp: 49840
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.0847260178207455
#     Experience: 1
#     Action Set Size: 8.0
#     Numerosity: 1
# 10#####1#0# => True
#     Time Stamp: 49978
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.08655834210457897
#     Experience: 5
#     Action Set Size: 11.4
#     Numerosity: 1
# 100######## => True
#     Time Stamp: 49978
#     Average Reward: 0.7787934170574172
#     Error: 0.3360076213578156
#     Fitness: 0.0870846933561989
#     Experience: 18
#     Action Set Size: 9.154318420205879
#     Numerosity: 1
# 110######01 => True
#     Time Stamp: 49637
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.09065517977129688
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 1#10##0###0 => True
#     Time Stamp: 49968
#     Average Reward: 0.1479017708333334
#     Error: 0.25143301041666666
#     Fitness: 0.09100558064176573
#     Experience: 11
#     Action Set Size: 7.949649895833334
#     Numerosity: 1
# 1#10###11## => True
#     Time Stamp: 49934
#     Average Reward: 0.75
#     Error: 0.27083333333333337
#     Fitness: 0.0912247963087135
#     Experience: 4
#     Action Set Size: 10.75
#     Numerosity: 1
# 10########1 => True
#     Time Stamp: 49995
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.1003163069435904
#     Experience: 4
#     Action Set Size: 12.25
#     Numerosity: 1
# 010##00#### => True
#     Time Stamp: 49751
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.1006841278970063
#     Experience: 3
#     Action Set Size: 10.666666666666666
#     Numerosity: 1
# ########0## => False
#     Time Stamp: 49983
#     Average Reward: 0.8027492933718021
#     Error: 0.3024039145258438
#     Fitness: 0.10125266030462603
#     Experience: 107
#     Action Set Size: 14.882730909037619
#     Numerosity: 1
# 0#1#0###110 => True
#     Time Stamp: 49840
#     Average Reward: 0.33333333333333337
#     Error: 0.2777777777777778
#     Fitness: 0.10397959920302419
#     Experience: 3
#     Action Set Size: 4.666666666666667
#     Numerosity: 1
# 10##0##1### => True
#     Time Stamp: 49970
#     Average Reward: 0.75
#     Error: 0.27083333333333337
#     Fitness: 0.11209893736191204
#     Experience: 4
#     Action Set Size: 10.5
#     Numerosity: 1
# 0000#0##### => True
#     Time Stamp: 49987
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.11218869456342237
#     Experience: 5
#     Action Set Size: 12.0
#     Numerosity: 1
# 0000###1### => True
#     Time Stamp: 49987
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.11416122849410937
#     Experience: 12
#     Action Set Size: 11.791302580729166
#     Numerosity: 1
# #0###100### => True
#     Time Stamp: 49995
#     Average Reward: 0.8333333333333334
#     Error: 0.16111111111111112
#     Fitness: 0.11721387556282062
#     Experience: 6
#     Action Set Size: 8.666666666666666
#     Numerosity: 1
# 010##0###1# => True
#     Time Stamp: 49639
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.11801533368192042
#     Experience: 5
#     Action Set Size: 7.8
#     Numerosity: 1
# ##10###0#1# => True
#     Time Stamp: 49995
#     Average Reward: 0.3333333333333333
#     Error: 0.22222222222222224
#     Fitness: 0.12088206477556855
#     Experience: 3
#     Action Set Size: 9.666666666666666
#     Numerosity: 1
# 1000#0###0# => True
#     Time Stamp: 49970
#     Average Reward: 0.6666666666666666
#     Error: 0.2777777777777778
#     Fitness: 0.12773232086859887
#     Experience: 3
#     Action Set Size: 10.0
#     Numerosity: 1
# #01#1###1#1 => True
#     Time Stamp: 49995
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.13176146499489677
#     Experience: 6
#     Action Set Size: 12.833333333333332
#     Numerosity: 1
# #01#1###0## => True
#     Time Stamp: 49936
#     Average Reward: 0.5
#     Error: 0.25
#     Fitness: 0.1325844525584713
#     Experience: 2
#     Action Set Size: 9.5
#     Numerosity: 1
# 010##0####1 => True
#     Time Stamp: 49890
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.1374096802682636
#     Experience: 4
#     Action Set Size: 15.0
#     Numerosity: 1
# 10#####11## => True
#     Time Stamp: 49970
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.14492410641838724
#     Experience: 14
#     Action Set Size: 11.35638880547526
#     Numerosity: 1
# #11##01##01 => True
#     Time Stamp: 49962
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.15142000100035397
#     Experience: 5
#     Action Set Size: 13.6
#     Numerosity: 1
# 1#111#0##01 => True
#     Time Stamp: 49821
#     Average Reward: 0.75
#     Error: 0.22916666666666669
#     Fitness: 0.15755395912851836
#     Experience: 4
#     Action Set Size: 10.25
#     Numerosity: 1
# ###1####0## => False
#     Time Stamp: 49983
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.16117769280526908
#     Experience: 1
#     Action Set Size: 17.0
#     Numerosity: 1
# 1#1#1###1#1 => True
#     Time Stamp: 49995
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.16472210753183744
#     Experience: 7
#     Action Set Size: 8.9
#     Numerosity: 1
# 011##0##### => True
#     Time Stamp: 49921
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.16530411318611338
#     Experience: 1
#     Action Set Size: 6.0
#     Numerosity: 1
# 101#1##0##0 => True
#     Time Stamp: 49584
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.1731165491105812
#     Experience: 1
#     Action Set Size: 4.0
#     Numerosity: 1
# 1#10######0 => True
#     Time Stamp: 49968
#     Average Reward: 0.2
#     Error: 0.22333333333333336
#     Fitness: 0.17601529781773592
#     Experience: 5
#     Action Set Size: 8.6
#     Numerosity: 1
# #111#1###00 => True
#     Time Stamp: 49546
#     Average Reward: 0.25
#     Error: 0.27083333333333337
#     Fitness: 0.1819538382801409
#     Experience: 4
#     Action Set Size: 6.25
#     Numerosity: 1
# 001#0###### => True
#     Time Stamp: 49902
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.19997996607476953
#     Experience: 3
#     Action Set Size: 8.0
#     Numerosity: 1
# #1##1###### => True
#     Time Stamp: 49968
#     Average Reward: 0.2
#     Error: 0.16000000000000003
#     Fitness: 0.22157713990876016
#     Experience: 5
#     Action Set Size: 12.0
#     Numerosity: 1
# 011###1###1 => True
#     Time Stamp: 49691
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.22855726395393658
#     Experience: 16
#     Action Set Size: 13.02286804921429
#     Numerosity: 1
# 10#####00## => True
#     Time Stamp: 49723
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.23133964407702282
#     Experience: 3
#     Action Set Size: 6.666666666666667
#     Numerosity: 1
# 001#0##1### => True
#     Time Stamp: 49902
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.254152047233842
#     Experience: 3
#     Action Set Size: 8.0
#     Numerosity: 1
# 110###1##1# => True
#     Time Stamp: 49950
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.2866134166634764
#     Experience: 17
#     Action Set Size: 10.789587555436867
#     Numerosity: 1
# ##0#0####1# => False
#     Time Stamp: 49983
#     Average Reward: 0.6950229973958334
#     Error: 0.3191443166232639
#     Fitness: 0.3487317777741755
#     Experience: 12
#     Action Set Size: 14.858208653645832
#     Numerosity: 1
# 111#####001 => True
#     Time Stamp: 49962
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.3502656563704988
#     Experience: 24
#     Action Set Size: 14.261008927901605
#     Numerosity: 1
# #1###1###1# => True
#     Time Stamp: 49968
#     Average Reward: 0.6634176000928032
#     Error: 0.3905952640784942
#     Fitness: 0.005153981949120137
#     Experience: 20
#     Action Set Size: 14.22770526169197
#     Numerosity: 2
# #01#1###### => True
#     Time Stamp: 49995
#     Average Reward: 0.8880291156184896
#     Error: 0.2056455493892144
#     Fitness: 0.02218991755827838
#     Experience: 14
#     Action Set Size: 11.382500656751303
#     Numerosity: 2
# 001######## => True
#     Time Stamp: 49993
#     Average Reward: 0.5595273210914433
#     Error: 0.4361555047390151
#     Fitness: 0.026258565360128203
#     Experience: 73
#     Action Set Size: 10.074563165088282
#     Numerosity: 2
# 1#1###0#### => True
#     Time Stamp: 49995
#     Average Reward: 0.5
#     Error: 0.25
#     Fitness: 0.03661048587200194
#     Experience: 2
#     Action Set Size: 11.0
#     Numerosity: 2
# 001####1### => True
#     Time Stamp: 49993
#     Average Reward: 0.5726662630208333
#     Error: 0.4050505951822917
#     Fitness: 0.05540457081835992
#     Experience: 12
#     Action Set Size: 10.376376213541667
#     Numerosity: 2
# #11###1#### => True
#     Time Stamp: 49964
#     Average Reward: 0.6841971204427084
#     Error: 0.36809159311197914
#     Fitness: 0.06231026004846945
#     Experience: 13
#     Action Set Size: 10.129629953385416
#     Numerosity: 2
# ##1######## => False
#     Time Stamp: 49937
#     Average Reward: 0.8149907836535439
#     Error: 0.3164310706543278
#     Fitness: 0.06512378001712606
#     Experience: 632
#     Action Set Size: 14.94379814347294
#     Numerosity: 2
# #111#11#0#0 => True
#     Time Stamp: 49738
#     Average Reward: 0.5
#     Error: 0.25
#     Fitness: 0.07111994034090215
#     Experience: 2
#     Action Set Size: 4.5
#     Numerosity: 2
# 101####1### => True
#     Time Stamp: 49934
#     Average Reward: 0.5259023787709659
#     Error: 0.43349479955235176
#     Fitness: 0.07251824861542297
#     Experience: 31
#     Action Set Size: 9.717246737170518
#     Numerosity: 2
# 1#10##0#### => True
#     Time Stamp: 49995
#     Average Reward: 0.5379222916666666
#     Error: 0.40449596354166667
#     Fitness: 0.07670082220355769
#     Experience: 11
#     Action Set Size: 11.05011484375
#     Numerosity: 2
# 110######00 => True
#     Time Stamp: 49843
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.0924125694219482
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 2
# 100####11## => True
#     Time Stamp: 49970
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.09601205592361078
#     Experience: 3
#     Action Set Size: 10.333333333333334
#     Numerosity: 2
# 00##1#1#### => True
#     Time Stamp: 49987
#     Average Reward: 0.8
#     Error: 0.16000000000000003
#     Fitness: 0.10477996973039334
#     Experience: 5
#     Action Set Size: 13.0
#     Numerosity: 2
# #10######1# => True
#     Time Stamp: 49950
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.1276328905053717
#     Experience: 9
#     Action Set Size: 14.7298125
#     Numerosity: 2
# 101###0#### => True
#     Time Stamp: 49995
#     Average Reward: 0.7166666666666667
#     Error: 0.28097222222222223
#     Fitness: 0.14769759066906693
#     Experience: 7
#     Action Set Size: 9.75
#     Numerosity: 2
# 101#01101#1 => True
#     Time Stamp: 49507
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.15000850000000002
#     Experience: 1
#     Action Set Size: 1.0
#     Numerosity: 2
# 110###0##1# => True
#     Time Stamp: 49926
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.19177676214797018
#     Experience: 14
#     Action Set Size: 12.063420528821615
#     Numerosity: 2
# 00#11##1### => True
#     Time Stamp: 49993
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.20376613288931272
#     Experience: 18
#     Action Set Size: 15.525312801462423
#     Numerosity: 2
# 10000##0### => True
#     Time Stamp: 49806
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.2878964216597484
#     Experience: 2
#     Action Set Size: 6.0
#     Numerosity: 2
# #########0# => False
#     Time Stamp: 49957
#     Average Reward: 0.9339341000532446
#     Error: 0.17580379430314827
#     Fitness: 0.37336595219160273
#     Experience: 35
#     Action Set Size: 15.290229002496355
#     Numerosity: 2
# 110######1# => True
#     Time Stamp: 49950
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.3759514335104017
#     Experience: 769
#     Action Set Size: 11.762099654084922
#     Numerosity: 2
# 010##0##### => True
#     Time Stamp: 49960
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.533365324489684
#     Experience: 205
#     Action Set Size: 11.456683551951253
#     Numerosity: 2
# #11#######1 => True
#     Time Stamp: 49966
#     Average Reward: 0.6131488106362375
#     Error: 0.38949922280998184
#     Fitness: 0.05259247522762107
#     Experience: 101
#     Action Set Size: 11.249408144151623
#     Numerosity: 3
# 0001##0#### => True
#     Time Stamp: 49965
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.10010110936401244
#     Experience: 4
#     Action Set Size: 16.25
#     Numerosity: 3
# ####0#1#### => False
#     Time Stamp: 49983
#     Average Reward: 0.7880312135944728
#     Error: 0.3329395016323163
#     Fitness: 0.1026478098692107
#     Experience: 57
#     Action Set Size: 16.58256950853001
#     Numerosity: 3
# #10##1##### => True
#     Time Stamp: 49980
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.24661387282150254
#     Experience: 20
#     Action Set Size: 16.065944011773556
#     Numerosity: 3
# 010##01#1## => True
#     Time Stamp: 49960
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.25283779384056576
#     Experience: 6
#     Action Set Size: 12.0
#     Numerosity: 3
# 0########## => False
#     Time Stamp: 49957
#     Average Reward: 0.8306756012389322
#     Error: 0.2658017272396864
#     Fitness: 0.32284663867635355
#     Experience: 15
#     Action Set Size: 16.4974387900957
#     Numerosity: 3
# 001#1###### => True
#     Time Stamp: 49993
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.5054741105193185
#     Experience: 44
#     Action Set Size: 12.12906262572067
#     Numerosity: 3
# 101####11## => True
#     Time Stamp: 49934
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.6046614038820011
#     Experience: 29
#     Action Set Size: 11.425402560451763
#     Numerosity: 3
# 110######0# => True
#     Time Stamp: 49843
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.924125694219482
#     Experience: 70
#     Action Set Size: 7.520375828359547
#     Numerosity: 3
# 11#1#1##### => True
#     Time Stamp: 49964
#     Average Reward: 0.8
#     Error: 0.16000000000000003
#     Fitness: 0.20373667652018235
#     Experience: 5
#     Action Set Size: 14.8
#     Numerosity: 4
# 100####1### => True
#     Time Stamp: 49978
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.6799140909959224
#     Experience: 263
#     Action Set Size: 11.131163913822324
#     Numerosity: 4
# 010##1##### => True
#     Time Stamp: 49980
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.6819925224215757
#     Experience: 1625
#     Action Set Size: 18.026429453535016
#     Numerosity: 8
# 0001####### => True
#     Time Stamp: 49965
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.8157891624151895
#     Experience: 1672
#     Action Set Size: 14.158834749200926
#     Numerosity: 8
# 0000####### => True
#     Time Stamp: 49987
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.8352575487357687
#     Experience: 342
#     Action Set Size: 11.213872332721953
#     Numerosity: 8
# ########### => False
#     Time Stamp: 49983
#     Average Reward: 0.8503367425300451
#     Error: 0.2866700095727848
#     Fitness: 0.2955495755867321
#     Experience: 8600
#     Action Set Size: 15.431049325646923
#     Numerosity: 9
